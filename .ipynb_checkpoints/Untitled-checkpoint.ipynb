# %%
import os
import shutil
import random

# %%
source_dir_fire = "datasetFire/dataset/Fire"
source_dir_nonfire = "datasetFire/dataset/Non_fire"
source_dir_smoke = "datasetFire/dataset/Smoke"

train_dir = "datasetFire/train"
validation_dir = "datasetFire/validation"
test_dir = "datasetFire/test"

# %%
os.makedirs(train_dir, exist_ok=True)
os.makedirs(validation_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

train_ratio = 0.7
validation_ratio = 0.15
test_ratio = 0.15
listeDer=[source_dir_fire,source_dir_nonfire,source_dir_smoke]
label=[]
files

# %%
# destribuer les donnee de chaque dossies dans train:test:val  et creation des labels
files = os.listdir(source_dir_fire)#derectory fire 
#files.append(files1)

size=len(files1)
labels=["Fire" for _ in range(size)]
files1 = os.listdir(source_dir_nonfire)
files.append(files1)
size=len(files1)
labels.append(["non_fire" for _ in range(size)])
files1 = os.listdir(source_dir_smoke)
files.append(files1)
size=len(files1)
labels.append(["Smoke" for _ in range(size)])

print(files)
# Out:
# ['Fire1.png', 'Fire10.png', 'Fire100.png', 'Fire1000.png', 'Fire1001.png', 'Fire1002.png', 'Fire1003.png', 'Fire1004.png', 'Fire1005.png', 'Fire1006.png', 'Fire1007.png', 'Fire1008.png', 'Fire1009.png', 'Fire101.png', 'Fire1010.png', 'Fire1011.png', 'Fire1012.png', 'Fire1013.png', 'Fire1014.png', 'Fire1015.png', 'Fire1016.png', 'Fire1017.png', 'Fire1018.png', 'Fire1019.png', 'Fire102.png', 'Fire1020.png', 'Fire1021.png', 'Fire1022.png', 'Fire1023.png', 'Fire1024.png', 'Fire1025.png', 'Fire1026.png', 'Fire1027.png', 'Fire1028.png', 'Fire1029.png', 'Fire103.png', 'Fire1030.png', 'Fire1031.png', 'Fire1032.png', 'Fire1033.png', 'Fire1034.png', 'Fire1035.png', 'Fire1036.png', 'Fire1037.png', 'Fire1038.png', 'Fire1039.png', 'Fire104.png', 'Fire1040.png', 'Fire1041.png', 'Fire1042.png', 'Fire1043.png', 'Fire1044.png', 'Fire1045.png', 'Fire1046.png', 'Fire1047.png', 'Fire1048.png', 'Fire1049.png', 'Fire105.png', 'Fire1050.png', 'Fire1051.png', 'Fire1052.png', 'Fire1053.png', 'Fire1054.png', 
# ...

# %%
print("Shuffled Filenames:", shuffled_files)
print("Shuffled Labels:", shuffled_labels)
# Out:
# Shuffled Filenames: ('Fire3400.jpg', 'Fire3319.jpg', 'Fire3006.jpg', 'Fire4854.jpg', 'Fire155.png', 'Fire3647.jpg', 'Fire2531.jpg', 'Fire2667.jpg', 'Fire4107.jpg', 'Fire216.png', 'Fire2773.jpg', 'Fire2349.jpg', 'Fire1096.png', 'Fire4834.jpg', 'Fire560.png', 'Fire3051.jpg', 'Fire933.png', 'Fire945.png', 'Fire5349.jpg', 'Fire3292.jpg', 'Fire363.png', 'Fire1214.png', 'Fire683.png', 'Fire1656.png', 'Fire1938.jpg', 'Fire3176.jpg', 'Fire3629.jpg', 'Fire2416.jpg', 'Fire1149.png', 'Fire3630.jpg', 'Fire3793.jpg', 'Fire2631.jpg', 'Fire2067.jpg', 'Fire1448.png', 'Fire631.png', 'Fire3923.jpg', 'Fire4255.jpg', 'Fire864.png', 'Fire4133.jpg', 'Fire5341.jpg', 'Fire1543.png', 'Fire4453.jpg', 'Fire1193.png', 'Fire2627.jpg', 'Fire4156.jpg', 'Fire312.png', 'Fire4205.jpg', 'Fire3237.jpg', 'Fire3454.jpg', 'Fire4538.jpg', 'Fire439.png', 'Fire960.png', 'Fire722.png', 'Fire2992.jpg', 'Fire1298.png', 'Fire4617.jpg', 'Fire4157.jpg', 'Fire4529.jpg', 'Fire2246.jpg', 'Fire1953.jpg', 'Fire293.png', 'Fire2363.jpg',
# ...
